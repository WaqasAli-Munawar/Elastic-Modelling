# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.compose import TransformedTargetRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import mean_squared_error, r2_score,make_scorer
from sklearn.compose import ColumnTransformer
import warnings
from sklearn.model_selection import cross_validate

warnings.simplefilter(action='ignore', category=FutureWarning)

import seaborn as sns
import matplotlib.pyplot as plt

# %%
scope_data = pd.read_csv("scope_data.csv")

# %%
scope_data = scope_data.dropna()

# %%
scope_data.shape
# Out:
# (1791, 13)

# %%
plt.scatter(scope_data["total_wgt"], scope_data["avg_unit_price_adj"])
plt.xlabel("total_wgt")
plt.ylabel("avg_unit_price_adj")
plt.title("total_wgt vs. avg_unit_price_adj Scatter Plot")
plt.show()

# %%
scope_data.avg_unit_price_adj.max()
# Out:
# 2.24578091622427

# %%
d = scope_data["avg_unit_price_adj"].describe()
d
# Out:
# count    1791.000000
# mean        0.775227
# std         0.160662
# min         0.491980
# 25%         0.660999
# 50%         0.740019
# 75%         0.857930
# max         2.245781
# Name: avg_unit_price_adj, dtype: float64

# %%
IQR = d["75%"] - d["25%"]

# %%
lower_limit =d["25%"] -  IQR*1.5

# %%
upper_limit =d["75%"] +  IQR*1.5

# %%
upper_limit
# Out:
# 1.1533261150185437

# %%
upper_limit -  scope_data["avg_unit_price"].max()
# Out:
# -4.430381434799026

# %%
remove = scope_data["avg_unit_price_adj"].between(lower_limit,upper_limit).sum()
remove
# Out:
# 1733

# %%
scope_data.shape[0] - remove
# Out:
# 58

# %%
scope_data = scope_data[scope_data["avg_unit_price_adj"].between(lower_limit,upper_limit )]

# %%
scope_data.shape
# Out:
# (1733, 13)

# %%
d = scope_data["avg_unit_price_adj"].describe()
d
# Out:
# count    1733.000000
# mean        0.757965
# std         0.129128
# min         0.491980
# 25%         0.659185
# 50%         0.735588
# 75%         0.840514
# max         1.152588
# Name: avg_unit_price_adj, dtype: float64

# %%
sns.boxplot(scope_data["avg_unit_price_adj"])
plt.show()

# %%
plt.scatter(scope_data["total_wgt"], scope_data["avg_unit_price_adj"])
plt.xlabel("total_wgt")
plt.ylabel("avg_unit_price_adj")
plt.title("total_wgt vs. avg_unit_price_adj Scatter Plot")
plt.show()

# %%
def season(month):
    if month in (3, 4, 5):
        return "Spring"
    elif month in (6,7,8):
        return "Summer"
    elif month in (9,10,11):
        return "Fall"
    else:
        return "Winter"

# %%
scope_data['season'] = scope_data["month"].apply(season)

# %%
scope_data.head(5)
# Out:
#    Unnamed: 0 fisc_wk_strt_dt  month  year  week_of_month mkt_lvl    value  \
# 0           1      2013-05-05      5  2013             18   North  236.526
# 1           2      2013-05-05      5  2013             18   South  236.526
# 2           3      2013-05-05      5  2013             18    West  236.526
# 3           4      2013-05-12      5  2013             19   North  236.526
# 4           5      2013-05-12      5  2013             19   South  236.526
#
#      total_wgt  total_sales  avg_unit_price  avg_unit_price_adj  log_price  \
# 0  1642565.196   3474335.31        2.115189            0.894273  -0.111744
# 1  1422200.660   2850561.14        2.004331            0.847404  -0.165578
# 2   694843.260   1440919.45        2.073733            0.876746  -0.131538
# 3  1587125.754   3533834.04        2.226562            0.941360  -0.060429
# 4  1376157.075   2888754.41        2.099146            0.887491  -0.119357
#
#    log_units  season
# 0  14.311770  Spring
# 1  14.167716  Spring
# 2  13.451442  Spring
# 3  14.277435  Spring
# 4  14.134805  Spring

# %%
def fit_ridge_tidymodels(data):
    # Prepare the data
    X = data[['log_price', 'month', 'week_of_month', 'year']]
    y = data['log_units']
    
    # Define pipeline for the model
    numeric_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler())
    ])
    
    preprocessor = ColumnTransformer(transformers=[
        ('num', numeric_transformer, X.columns)
    ])
    
    ridge_model = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('ridge', Ridge())
    ])
    
    # Define the hyperparameter grid for tuning
    param_grid = {
        'ridge__alpha': np.logspace(-6, -1, num=20),
    }
    
    # Create a 10-fold cross-validation object
    sales_cv = KFold(n_splits=10, shuffle=True, random_state=42)
    
    # Perform cross-validated grid search
    grid_search = GridSearchCV(
        ridge_model,
        param_grid=param_grid,
        cv=sales_cv,
        scoring={
            'rmse': make_scorer(mean_squared_error, squared=False),
            'r2': make_scorer(r2_score)
        },
        refit='rmse'
    )
    
    # Fit the model
    grid_search.fit(X, y)
    
    # Extract the best model
    best_model = grid_search.best_estimator_
    
    # Fit the best model on the whole dataset
    best_model.fit(X, y)
    
    # Extract the log_price coefficient
    coefficients = pd.DataFrame(
        best_model.named_steps['ridge'].coef_,
        index=X.columns,
        columns=['estimate']
    )
    normalized_stats = pd.DataFrame(
        best_model.named_steps['preprocessor'].named_transformers_['num']
        .named_steps['scaler'].var_,
        index=X.columns[:4],
        columns=['sd']
    )
    coefs_denormalized = coefficients.join(normalized_stats)
    coefs_denormalized['beta_denormalized'] = (
        coefs_denormalized['estimate'] / coefs_denormalized['sd']
    )
    log_price_beta = coefs_denormalized.loc['log_price', 'beta_denormalized']
    
    predict = best_model.predict(X)
    mse = mean_squared_error(y, predict)
    rmse = np.sqrt(mse)
    r2 = r2_score(y, predict)
    
    result = {
        'price_elasticity': log_price_beta,
        'rmse': rmse,
        'r2': r2
    }
    
    return result

# %%
combined_data_ridge = pd.DataFrame()

seasons = scope_data["season"].unique()

for s in seasons:
    season_df = scope_data[scope_data["season"] == s]
    df= season_df.groupby("mkt_lvl").apply(lambda x : pd.DataFrame({'data': [x]})).reset_index().drop(columns=['level_1'])
    applied = df["data"].apply(fit_ridge_tidymodels)
    for i, j in zip(df["mkt_lvl"], applied):
        j["mkt_lvl"] = i
        j["season"] = s
         
    for i in applied:
        dictionary = {"Season":i["season"], "mkt_lvl": i["mkt_lvl"], 
                              "Ridge_elast":i['price_elasticity'],
                             "Ridge_rmse":i['rmse'],
                      "Ridge_r2":i['r2']}
        combined_data_ridge = combined_data_ridge.append(dictionary, ignore_index=True)

# %%
combined_data_ridge
# Out:
#     Season mkt_lvl  Ridge_elast  Ridge_rmse  Ridge_r2
# 0   Spring   North    -6.182509    0.673257  0.192316
# 1   Spring   South     1.684183    1.005754  0.143894
# 2   Spring    West     1.589772    0.541335  0.228248
# 3   Summer   North    -3.509073    0.643131  0.190782
# 4   Summer   South    -0.564104    0.558167  0.206965
# 5   Summer    West     1.049147    0.521536  0.227288
# 6     Fall   North    -2.734128    0.612589  0.226088
# 7     Fall   South    -2.004981    0.525894  0.253293
# 8     Fall    West    -0.111746    0.512502  0.253297
# 9   Winter   North    -9.549992    0.742841  0.197353
# 10  Winter   South    -7.651903    0.699082  0.251112
# 11  Winter    West    -3.686375    0.542609  0.192017

# %%
from sklearn.metrics import r2_score

def fit_lasso_tidymodels(data):
    # Prepare the data
    X = data[['log_price', 'month', 'week_of_month', 'year']]
    y = data['log_units']
    
    # Define pipeline for the model
    numeric_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler())
    ])
    
    preprocessor = ColumnTransformer(transformers=[
        ('num', numeric_transformer, X.columns)
    ])
    
    lasso_model = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('lasso', Lasso())
    ])
    
    # Define the hyperparameter grid for tuning
    param_grid = {
        'lasso__alpha': np.logspace(-6, -1, num=20),
        'lasso__max_iter': [5000]
    }
    
    # Create a 10-fold cross-validation object
    sales_cv = KFold(n_splits=10, shuffle=True, random_state=42)
    
    # Perform cross-validated grid search
    grid_search = GridSearchCV(
        lasso_model,
        param_grid=param_grid,
        cv=sales_cv,
        scoring={
            'rmse': make_scorer(mean_squared_error, squared=False),
            'r2': make_scorer(r2_score)
        },
        refit='rmse'
    )
    
    # Fit the model
    grid_search.fit(X, y)
    
    # Extract the best model
    best_model = grid_search.best_estimator_
    
    # Fit the best model on the whole dataset
    best_model.fit(X, y)
    
    # Extract the log_price coefficient
    coefficients = pd.DataFrame(
        best_model.named_steps['lasso'].coef_,
        index=X.columns,
        columns=['estimate']
    )
    normalized_stats = pd.DataFrame(
        best_model.named_steps['preprocessor'].named_transformers_['num']
        .named_steps['scaler'].var_,
        index=X.columns[:4],
        columns=['sd']
    )
    coefs_denormalized = coefficients.join(normalized_stats)
    coefs_denormalized['beta_denormalized'] = (
        coefs_denormalized['estimate'] / coefs_denormalized['sd']
    )
    log_price_beta = coefs_denormalized.loc['log_price', 'beta_denormalized']
    
    predict = best_model.predict(X)
    mse = mean_squared_error(y, predict)
    rmse = np.sqrt(mse)
    r2 = r2_score(y, predict)
    
    result = {
        'price_elasticity': log_price_beta,
        'rmse': rmse,
        'r2': r2
    }
    
    return result

# %%
combined_data_lasso = pd.DataFrame()

seasons = scope_data["season"].unique()

for s in seasons:
    season_df = scope_data[scope_data["season"] == s]
    df= season_df.groupby("mkt_lvl").apply(lambda x : pd.DataFrame({'data': [x]})).reset_index().drop(columns=['level_1'])
    applied = df["data"].apply(fit_lasso_tidymodels)
    for i, j in zip(df["mkt_lvl"], applied):
        j["mkt_lvl"] = i
        j["season"] = s
         
    for i in applied:
        dictionary = {"Season":i["season"], "mkt_lvl": i["mkt_lvl"], 
                              "lasso_elast":i['price_elasticity'],
                             "lasso_rmse":i['rmse'],
                      "lasso_r2":i['r2']}
        combined_data_lasso = combined_data_lasso.append(dictionary, ignore_index=True)

# %%
combined_data_lasso
# Out:
#     Season mkt_lvl  lasso_elast  lasso_rmse  lasso_r2
# 0   Spring   North    -3.177637    0.740270  0.023529
# 1   Spring   South     0.000000    1.081368  0.010329
# 2   Spring    West     0.000000    0.616154  0.000177
# 3   Summer   North    -0.000000    0.712847  0.005831
# 4   Summer   South    -0.000000    0.623574  0.010217
# 5   Summer    West     0.000000    0.592941  0.001213
# 6     Fall   North    -0.000000    0.690195  0.017580
# 7     Fall   South    -0.000000    0.608588  0.000000
# 8     Fall    West     0.000000    0.590455  0.008873
# 9   Winter   North    -8.668766    0.807641  0.051213
# 10  Winter   South    -8.030898    0.766696  0.099245
# 11  Winter    West    -3.574698    0.594429  0.030321

# %%
def fit_elasticnet_tidymodels(data):
    # Prepare the data
    X = data[['log_price', 'month', 'week_of_month', 'year']]
    y = data['log_units']
    
    # Define pipeline for the model
    numeric_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler())
    ])
    
    preprocessor = ColumnTransformer(transformers=[
        ('num', numeric_transformer, X.columns)
    ])
    
    elasticnet_model = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('elasticnet', ElasticNet())
    ])
    
    # Define the hyperparameter grid for tuning
    param_grid = {
        'elasticnet__alpha': np.logspace(-6, -1, num=20),
        'elasticnet__l1_ratio': [0.5],
        'elasticnet__max_iter': [5000]
    }
    
    # Create a 10-fold cross-validation object
    sales_cv = KFold(n_splits=10, shuffle=True, random_state=42)
    
    # Perform cross-validated grid search
    grid_search = GridSearchCV(
        elasticnet_model,
        param_grid=param_grid,
        cv=sales_cv,
        scoring={
            'rmse': make_scorer(mean_squared_error, squared=False),
            'r2': make_scorer(r2_score)
        },
        refit='rmse'
    )
    
    # Fit the model
    grid_search.fit(X, y)
    
    # Extract the best model
    best_model = grid_search.best_estimator_
    
    # Fit the best model on the whole dataset
    best_model.fit(X, y)
    
    # Extract the log_price coefficient
    coefficients = pd.DataFrame(
        best_model.named_steps['elasticnet'].coef_,
        index=X.columns,
        columns=['estimate']
    )
    normalized_stats = pd.DataFrame(
        best_model.named_steps['preprocessor'].named_transformers_['num']
        .named_steps['scaler'].var_,
        index=X.columns[:4],
        columns=['sd']
    )
    coefs_denormalized = coefficients.join(normalized_stats)
    coefs_denormalized['beta_denormalized'] = (
        coefs_denormalized['estimate'] / coefs_denormalized['sd']
    )
    log_price_beta = coefs_denormalized.loc['log_price', 'beta_denormalized']
    
    predict = best_model.predict(X)
    mse = mean_squared_error(y, predict)
    rmse = np.sqrt(mse)
    r2 = r2_score(y, predict)
    
    result = {
        'price_elasticity': log_price_beta,
        'rmse': rmse,
        'r2': r2
    }
    
    return result

# %%
combined_data_elasticnet = pd.DataFrame()

seasons = scope_data["season"].unique()

for s in seasons:
    season_df = scope_data[scope_data["season"] == s]
    df= season_df.groupby("mkt_lvl").apply(lambda x : pd.DataFrame({'data': [x]})).reset_index().drop(columns=['level_1'])
    applied = df["data"].apply(fit_elasticnet_tidymodels)
    for i, j in zip(df["mkt_lvl"], applied):
        j["mkt_lvl"] = i
        j["season"] = s
         
    for i in applied:
        dictionary = {"Season":i["season"], "mkt_lvl": i["mkt_lvl"], 
                              "ElasticNet_elast":i['price_elasticity'],
                             "ElasticNet_rmse":i['rmse'],
                             "ElasticNet_r2":i['r2']}
        combined_data_elasticnet = combined_data_elasticnet.append(dictionary, ignore_index=True)

# %%
combined_data_elasticnet
# Out:
#     Season mkt_lvl  ElasticNet_elast  ElasticNet_rmse  ElasticNet_r2
# 0   Spring   North         -3.311590         0.735806       0.035270
# 1   Spring   South          0.000000         1.061291       0.046737
# 2   Spring    West          0.000000         0.607563       0.027861
# 3   Summer   North         -0.494801         0.707198       0.021528
# 4   Summer   South         -0.000000         0.623130       0.011624
# 5   Summer    West          0.000000         0.586050       0.024293
# 6     Fall   North         -0.000000         0.682106       0.040472
# 7     Fall   South         -0.000000         0.600466       0.026513
# 8     Fall    West          0.000000         0.584340       0.029294
# 9   Winter   North         -8.612486         0.807649       0.051194
# 10  Winter   South         -7.968441         0.766725       0.099176
# 11  Winter    West         -3.576954         0.594411       0.030380

# %%
def fit_linear_tidymodels(data):
    # Prepare the data
    X = data[['log_price', 'month', 'week_of_month', 'year']]
    y = data['log_units']

    # Define pipeline for the model
    numeric_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler())
    ])

    preprocessor = ColumnTransformer(transformers=[
        ('num', numeric_transformer, X.columns)
    ])

    linear_model = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('linear', LinearRegression())
    ])

    # Create a 10-fold cross-validation object
    sales_cv = KFold(n_splits=10, shuffle=True, random_state=42)

    # Lists to store results
    rmse_scores = []
    r2_scores = []
    best_model = None
    best_rmse = float('inf')
    best_r2 = None

    # Perform cross-validated training and evaluation
    for train_index, test_index in sales_cv.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Fit the model
        linear_model.fit(X_train, y_train)

        # Evaluate the model
        predict = linear_model.predict(X_test)
        mse = mean_squared_error(y_test, predict)
        rmse = np.sqrt(mse)
        rmse_scores.append(rmse)
        r2 = r2_score(y_test, predict)
        r2_scores.append(r2)

        # Track the best model based on RMSE
        if rmse < best_rmse:
            best_model = linear_model
            best_rmse = rmse
            best_r2 = r2

    # Fit the best model on the whole dataset
    best_model.fit(X, y)

    # Extract the log_price coefficient
    coefficients = pd.DataFrame(
        best_model.named_steps['linear'].coef_,
        index=X.columns,
        columns=['estimate']
    )
    normalized_stats = pd.DataFrame(
        best_model.named_steps['preprocessor']
        .named_transformers_['num']
        .named_steps['scaler']
        .var_,
        index=X.columns[:4],
        columns=['sd']
    )
    coefs_denormalized = coefficients.join(normalized_stats)
    coefs_denormalized['beta_denormalized'] = (
        coefs_denormalized['estimate'] / coefs_denormalized['sd']
    )
    log_price_beta = coefs_denormalized.loc['log_price', 'beta_denormalized']

    adjusted_r2 = best_r2
    if adjusted_r2 < 0:
        adjusted_r2 = 1 - (1 - adjusted_r2) * ((len(y) - 1) / (len(y) - X.shape[1] - 1))

    avg_rmse = np.mean(rmse_scores)

    result = {'price_elasticity': log_price_beta, 'rmse': avg_rmse, 'r2': adjusted_r2}

    return result

# %%
combined_data_linear = pd.DataFrame()

seasons = scope_data["season"].unique()

for s in seasons:
    season_df = scope_data[scope_data["season"] == s]
    df= season_df.groupby("mkt_lvl").apply(lambda x :pd.DataFrame({'data': [x]})).reset_index().drop(columns=['level_1'])
    applied = df["data"].apply(fit_linear_tidymodels)
    for i, j in zip(df["mkt_lvl"], applied):
        j["mkt_lvl"] = i
        j["season"] = s
         
    for i in applied:
        dictionary = {"Season":i["season"], "mkt_lvl": i["mkt_lvl"], 
                              "linear_elast":i['price_elasticity'],
                             "linear_rmse":i['rmse'],
                            "linear_r2":i['r2']}
        combined_data_linear = combined_data_linear.append(dictionary, ignore_index=True)

# %%
combined_data_linear
# Out:
#     Season mkt_lvl  linear_elast  linear_rmse  linear_r2
# 0   Spring   North     -6.182509     0.638481  -0.055306
# 1   Spring   South      1.684183     0.763850   0.715614
# 2   Spring    West      1.589772     0.517935   0.300698
# 3   Summer   North     -3.509073     0.579058  -1.223043
# 4   Summer   South     -0.564104     0.527615   0.175673
# 5   Summer    West      1.049147     0.484055   0.575594
# 6     Fall   North     -2.734129     0.597715  -0.645297
# 7     Fall   South     -2.004981     0.517863  -0.355114
# 8     Fall    West     -0.111747     0.505919  -0.384745
# 9   Winter   North     -9.549992     0.674599  -0.935176
# 10  Winter   South     -7.651899     0.681551   0.224903
# 11  Winter    West     -3.597773     0.524645   0.268964

# %%
all_data =  [combined_data_linear, combined_data_ridge, combined_data_lasso, combined_data_elasticnet]

for i in range(len(all_data)-1):
    
    if i == 0:
        combined1 = pd.merge(all_data[i], all_data[i+1], on =["Season", "mkt_lvl"], how = "inner")
    else:
        combined1 = combined1.merge(all_data[i+1], on =["Season", "mkt_lvl"], how = "inner")

# %%
combined1
# Out:
#     Season mkt_lvl  linear_elast  linear_rmse  linear_r2  Ridge_elast  \
# 0   Spring   North     -6.182509     0.638481  -0.055306    -6.182509
# 1   Spring   South      1.684183     0.763850   0.715614     1.684183
# 2   Spring    West      1.589772     0.517935   0.300698     1.589772
# 3   Summer   North     -3.509073     0.579058  -1.223043    -3.509073
# 4   Summer   South     -0.564104     0.527615   0.175673    -0.564104
# 5   Summer    West      1.049147     0.484055   0.575594     1.049147
# 6     Fall   North     -2.734129     0.597715  -0.645297    -2.734128
# 7     Fall   South     -2.004981     0.517863  -0.355114    -2.004981
# 8     Fall    West     -0.111747     0.505919  -0.384745    -0.111746
# 9   Winter   North     -9.549992     0.674599  -0.935176    -9.549992
# 10  Winter   South     -7.651899     0.681551   0.224903    -7.651903
# 11  Winter    West     -3.597773     0.524645   0.268964    -3.686375
#
#     Ridge_rmse  Ridge_r2  lasso_elast  lasso_rmse  lasso_r2  ElasticNet_elast  \
# 0     0.673257  0.192316    -3.177637    0.740270  0.023529         -3.311590
# 1     1.005754  0.143894     0.000000    1.081368  0.010329          0.000000
# 2     0.541335  0.228248     0.000000    0.616154  0.000177          0.000000
# 3     0.643131  0.190782    -0.000000    0.712847  0.005831         -0.494801
# 4     0.558167  0.206965    -0.000000    0.623574  0.010217         -0.000000
# 5     0.521536  0.227288     0.000000    0.592941  0.001213          0.000000
# 6     0.612589  0.226088    -0.000000    0.690195  0.017580         -0.000000
# 7     0.525894  0.253293    -0.000000    0.608588  0.000000         -0.000000
# 8     0.512502  0.253297     0.000000    0.590455  0.008873          0.000000
# 9     0.742841  0.197353    -8.668766    0.807641  0.051213         -8.612486
# 10    0.699082  0.251112    -8.030898    0.766696  0.099245         -7.968441
# 11    0.542609  0.192017    -3.574698    0.594429  0.030321         -3.576954
#
#     ElasticNet_rmse  ElasticNet_r2
# 0          0.735806       0.035270
# 1          1.061291       0.046737
# 2          0.607563       0.027861
# 3          0.707198       0.021528
# 4          0.623130       0.011624
# 5          0.586050       0.024293
# 6          0.682106       0.040472
# 7          0.600466       0.026513
# 8          0.584340       0.029294
# 9          0.807649       0.051194
# 10         0.766725       0.099176
# 11         0.594411       0.030380
